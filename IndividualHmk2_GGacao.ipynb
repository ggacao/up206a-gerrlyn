# %%
import geopandas as gpd

# %%
tracts = gpd.read_file('../../data/la_tracts.geojson')

# %%
type(tracts)
# Out:
# list

# %%
tracts.head(11)
# Out:
#                    kind  external_id         name  \
# 0   Census Tract (2012)  06037101110  06037101110
# 1   Census Tract (2012)  06037101122  06037101122
# 2   Census Tract (2012)  06037101210  06037101210
# 3   Census Tract (2012)  06037101220  06037101220
# 4   Census Tract (2012)  06037101300  06037101300
# 5   Census Tract (2012)  06037101400  06037101400
# 6   Census Tract (2012)  06037102103  06037102103
# 7   Census Tract (2012)  06037102104  06037102104
# 8   Census Tract (2012)  06037102105  06037102105
# 9   Census Tract (2012)  06037102107  06037102107
# 10  Census Tract (2012)  06037103101  06037103101
#
#                              slug                                    set  \
# 0   06037101110-census-tract-2012  /1.0/boundary-set/census-tracts-2012/
# 1   06037101122-census-tract-2012  /1.0/boundary-set/census-tracts-2012/
# 2   06037101210-census-tract-2012  /1.0/boundary-set/census-tracts-2012/
# ...

# %%
tracts.tail(10)
# Out:
#                      kind  external_id         name  \
# 2336  Census Tract (2012)  06037980024  06037980024
# 2337  Census Tract (2012)  06037980025  06037980025
# 2338  Census Tract (2012)  06037980026  06037980026
# 2339  Census Tract (2012)  06037980028  06037980028
# 2340  Census Tract (2012)  06037980030  06037980030
# 2341  Census Tract (2012)  06037980031  06037980031
# 2342  Census Tract (2012)  06037980033  06037980033
# 2343  Census Tract (2012)  06037990100  06037990100
# 2344  Census Tract (2012)  06037990200  06037990200
# 2345  Census Tract (2012)  06037990300  06037990300
#
#                                slug                                    set  \
# 2336  06037980024-census-tract-2012  /1.0/boundary-set/census-tracts-2012/
# 2337  06037980025-census-tract-2012  /1.0/boundary-set/census-tracts-2012/
# 2338  06037980026-census-tract-2012  /1.0/boundary-set/census-tracts-2012/
# 2339  06037980028-census-tract-2012  /1.0/boundary-set/census-tracts-2012/
# ...

# %%
tracts.sample(5)
# Out:
#                      kind  external_id         name  \
# 1308  Census Tract (2012)  06037432601  06037432601
# 2185  Census Tract (2012)  06037900608  06037900608
# 896   Census Tract (2012)  06037271802  06037271802
# 738   Census Tract (2012)  06037232120  06037232120
# 1594  Census Tract (2012)  06037533601  06037533601
#
#                                slug                                    set  \
# 1308  06037432601-census-tract-2012  /1.0/boundary-set/census-tracts-2012/
# 2185  06037900608-census-tract-2012  /1.0/boundary-set/census-tracts-2012/
# 896   06037271802-census-tract-2012  /1.0/boundary-set/census-tracts-2012/
# 738   06037232120-census-tract-2012  /1.0/boundary-set/census-tracts-2012/
# 1594  06037533601-census-tract-2012  /1.0/boundary-set/census-tracts-2012/
#
#                                                metadata  \
# 1308  {'INTPTLAT': '+34.0820032', 'NAME': '4326.01',...
# 2185  {'INTPTLAT': '+34.6968196', 'NAME': '9006.08',...
# ...

# %%
tracts.dtypes
# Out:
# kind              object
# external_id       object
# name              object
# slug              object
# set               object
# metadata          object
# resource_uri      object
# geometry        geometry
# dtype: object

# %%
tracts.info(10)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 2346 entries, 0 to 2345
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   kind          2346 non-null   object
#  1   external_id   2346 non-null   object
#  2   name          2346 non-null   object
#  3   slug          2346 non-null   object
#  4   set           2346 non-null   object
#  5   metadata      2346 non-null   object
#  6   resource_uri  2346 non-null   object
#  7   geometry      2346 non-null   geometry
# dtypes: geometry(1), object(7)
# memory usage: 146.8+ KB

# %%
tracts.shape
# Out:
# (2346, 8)

# %%
tracts.columns.to_list()
# Out:
# ['kind',
#  'external_id',
#  'name',
#  'slug',
#  'set',
#  'metadata',
#  'resource_uri',
#  'geometry']

# %%
tracts['name'].value_counts()
# Out:
# 06037131900    1
# 06037531604    1
# 06037189800    1
# 06037980028    1
# 06037542104    1
#               ..
# 06037311300    1
# 06037534802    1
# 06037403902    1
# 06037550100    1
# 06037570800    1
# Name: name, Length: 2346, dtype: int64

# %%
tracts.name
# Out:
# 0       06037101110
# 1       06037101122
# 2       06037101210
# 3       06037101220
# 4       06037101300
#            ...
# 2341    06037980031
# 2342    06037980033
# 2343    06037990100
# 2344    06037990200
# 2345    06037990300
# Name: name, Length: 2346, dtype: object

# %%
tracts[['external_id','name','slug','set','metadata']]
# Out:
#       external_id         name                           slug  \
# 0     06037101110  06037101110  06037101110-census-tract-2012
# 1     06037101122  06037101122  06037101122-census-tract-2012
# 2     06037101210  06037101210  06037101210-census-tract-2012
# 3     06037101220  06037101220  06037101220-census-tract-2012
# 4     06037101300  06037101300  06037101300-census-tract-2012
# ...           ...          ...                            ...
# 2341  06037980031  06037980031  06037980031-census-tract-2012
# 2342  06037980033  06037980033  06037980033-census-tract-2012
# 2343  06037990100  06037990100  06037990100-census-tract-2012
# 2344  06037990200  06037990200  06037990200-census-tract-2012
# 2345  06037990300  06037990300  06037990300-census-tract-2012
#
#                                         set  \
# 0     /1.0/boundary-set/census-tracts-2012/
# 1     /1.0/boundary-set/census-tracts-2012/
# 2     /1.0/boundary-set/census-tracts-2012/
# ...

# %%
tracts.head(11)
# Out:
#                    kind  external_id         name  \
# 0   Census Tract (2012)  06037101110  06037101110
# 1   Census Tract (2012)  06037101122  06037101122
# 2   Census Tract (2012)  06037101210  06037101210
# 3   Census Tract (2012)  06037101220  06037101220
# 4   Census Tract (2012)  06037101300  06037101300
# 5   Census Tract (2012)  06037101400  06037101400
# 6   Census Tract (2012)  06037102103  06037102103
# 7   Census Tract (2012)  06037102104  06037102104
# 8   Census Tract (2012)  06037102105  06037102105
# 9   Census Tract (2012)  06037102107  06037102107
# 10  Census Tract (2012)  06037103101  06037103101
#
#                              slug                                    set  \
# 0   06037101110-census-tract-2012  /1.0/boundary-set/census-tracts-2012/
# 1   06037101122-census-tract-2012  /1.0/boundary-set/census-tracts-2012/
# 2   06037101210-census-tract-2012  /1.0/boundary-set/census-tracts-2012/
# ...

# %%
tracts[['external_id','name','slug','set','metadata']]
# Out:
#       external_id         name                           slug  \
# 0     06037101110  06037101110  06037101110-census-tract-2012
# 1     06037101122  06037101122  06037101122-census-tract-2012
# 2     06037101210  06037101210  06037101210-census-tract-2012
# 3     06037101220  06037101220  06037101220-census-tract-2012
# 4     06037101300  06037101300  06037101300-census-tract-2012
# ...           ...          ...                            ...
# 2341  06037980031  06037980031  06037980031-census-tract-2012
# 2342  06037980033  06037980033  06037980033-census-tract-2012
# 2343  06037990100  06037990100  06037990100-census-tract-2012
# 2344  06037990200  06037990200  06037990200-census-tract-2012
# 2345  06037990300  06037990300  06037990300-census-tract-2012
#
#                                         set  \
# 0     /1.0/boundary-set/census-tracts-2012/
# 1     /1.0/boundary-set/census-tracts-2012/
# 2     /1.0/boundary-set/census-tracts-2012/
# ...

# %%
desired_columns = ['external_id','name','slug','set','metadata']

# %%
tracts[desired_columns]
# Out:
#       external_id         name                           slug  \
# 0     06037101110  06037101110  06037101110-census-tract-2012
# 1     06037101122  06037101122  06037101122-census-tract-2012
# 2     06037101210  06037101210  06037101210-census-tract-2012
# 3     06037101220  06037101220  06037101220-census-tract-2012
# 4     06037101300  06037101300  06037101300-census-tract-2012
# ...           ...          ...                            ...
# 2341  06037980031  06037980031  06037980031-census-tract-2012
# 2342  06037980033  06037980033  06037980033-census-tract-2012
# 2343  06037990100  06037990100  06037990100-census-tract-2012
# 2344  06037990200  06037990200  06037990200-census-tract-2012
# 2345  06037990300  06037990300  06037990300-census-tract-2012
#
#                                         set  \
# 0     /1.0/boundary-set/census-tracts-2012/
# 1     /1.0/boundary-set/census-tracts-2012/
# 2     /1.0/boundary-set/census-tracts-2012/
# ...

# %%
tracts.plot()

# %%
tracts.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich
